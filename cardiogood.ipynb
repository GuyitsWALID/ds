# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("CardioGoodFitness.csv")

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.5 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.5 kB 660.6 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/165.5 kB 469.7 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/165.5 kB 525.1 kB/s eta 0:00:01
#      -------------------------- --------- 122.9/165.5 kB 514.3 kB/s eta 0:00:01
#      ------------------------------------ 165.5/165.5 kB 663.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.0 MB 1.7 MB/s eta 0:00:05
#     --------------------------------------- 0.1/8.0 MB 1.7 MB/s eta 0:00:05
#     --------------------------------------- 0.2/8.0 MB 1.1 MB/s eta 0:00:07
# ...

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
#describe is only for numerical values it excludes Gender.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df_mean_Age = df['Age'].mean()

# %%
df_mean_Age
# Out:
# 28.788888888888888

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df_Asecnding = df.apply(np.sort, axis=0)
df_Asecnding
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18  Female         12     Partnered      2        1   29562
# 1     TM195   19  Female         12     Partnered      2        1   30699
# 2     TM195   19  Female         12     Partnered      2        2   31836
# 3     TM195   19  Female         13     Partnered      2        2   31836
# 4     TM195   19  Female         13     Partnered      2        2   32973
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   47    Male         18        Single      6        5   95866
# 176   TM798   47    Male         20        Single      6        5   99601
# 177   TM798   48    Male         21        Single      6        5  103336
# 178   TM798   48    Male         21        Single      7        5  104581
# 179   TM798   50    Male         21        Single      7        5  104581
#
#      Miles
# 0       21
# 1       38
# 2       38
# 3       38
# 4       42
# ...

# %%
df_Asecnding.plot.line('Fitness','Income')
df_Asecnding.plot.line('Age','Miles')
df_Asecnding.plot.line('Age','Income')
# Out:
# <Axes: xlabel='Age'>

# %%
df_Asecnding['Income'].max()
# Out:
# 104581

# %%
df_Asecnding.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000
